# %%
import os
import io
import pickle
from glob import glob

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from contextlib import contextmanager
from time import time
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
lgb_sub = pd.read_csv("/workspace/working/anime2vec/submission.csv")
svd_sub = pd.read_csv("/workspace/working/svdpp_pred/submission.csv")
# xgb_sub = pd.read_csv("/workspace/working/exp008_xgb/submission.csv")

# %%
plt.figure()
plt.hist(lgb_sub.score, alpha=0.2, bins=100, label="lgb")
plt.hist(svd_sub.score, alpha=0.2, bins=100, label="svd")
# plt.hist(xgb_sub.score, alpha=0.2, bins=100, label="xgb")
plt.legend()
plt.figure()

# %%
sub = (lgb_sub + svd_sub) / 2.0

# %%
sub.hist(bins=100)
# Out:
# array([[<Axes: title={'center': 'score'}>]], dtype=object)

# %%
sub
# Out:
#            score
# 0       7.901690
# 1       8.168579
# 2       6.522430
# 3       7.712302
# 4       4.964351
# ...          ...
# 117671  8.345284
# 117672  7.628487
# 117673  7.441907
# 117674  6.842750
# 117675  6.874920
#
# [117676 rows x 1 columns]

# %%
sub.to_csv(os.path.join("/workspace", "working", "lgb_svdpp", "submission.csv"), index=False)
