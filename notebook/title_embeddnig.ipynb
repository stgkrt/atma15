# %%
import os

import pandas as pd

# %%
class config:
    INPUT_DIR = os.path.join("/workspace", "input", "atmaCup15_dataset")

# %% [markdown]
# # anime csv

# %%
anime_df = pd.read_csv(os.path.join(config.INPUT_DIR, "anime.csv"))
train_df = pd.read_csv(os.path.join(config.INPUT_DIR, "train.csv"))

# %%
anime_df
# Out:
#                   anime_id                                             genres  \
# 0     000ba7f7e34e107e7544       Comedy, Sci-Fi, Seinen, Slice of Life, Space
# 1     00427279d72064e7fb69  Adventure, Slice of Life, Mystery, Historical,...
# 2     00444b67aaabdf740a68  Adventure, Slice of Life, Mystery, Historical,...
# 3     00839a3507ab168abe75                     Comedy, Ecchi, Fantasy, School
# 4     0192331235e110fe4f76     Comedy, Harem, Romance, Sci-Fi, Shounen, Space
# ...                    ...                                                ...
# 1995  ff73475b68001c5e533d  Adventure, Romance, Mecha, Military, Sci-Fi, H...
# 1996  ff8611bae4e43862381f                             Ecchi, Romance, School
# 1997  ffa143ffd4abec9d2707                  Action, Fantasy, Military, Sci-Fi
# 1998  ffb4819df40db39facfa         Action, Adventure, Fantasy, School, Sci-Fi
# 1999  ffc3cf0c5f60dd844611  Action, Mecha, Romance, Super Power, Supernatu...
#
#      japanese_name type episodes                         aired  \
# 0             宇宙兄弟   TV       99   Apr 1, 2012 to Mar 22, 2014
# 1               蟲師   TV       26  Oct 23, 2005 to Jun 19, 2006
# 2            蟲師 続章   TV       10   Apr 5, 2014 to Jun 21, 2014
# 3           星刻の竜騎士   TV       12   Apr 5, 2014 to Jun 21, 2014
# 4            天地無用！   TV       26   Apr 2, 1995 to Sep 24, 1995
# ...            ...  ...      ...                           ...
# 1995   BLUE GENDER   TV       26   Oct 8, 1999 to Mar 31, 2000
# 1996         フォトカノ   TV       13   Apr 5, 2013 to Jun 28, 2013
# 1997     GOD EATER   TV       13  Jul 12, 2015 to Mar 26, 2016
# 1998       鋼殻のレギオス   TV       24  Jan 11, 2009 to Jun 21, 2009
# 1999     創聖のアクエリオン   TV       26   Apr 5, 2005 to Sep 27, 2005
#
#                                               producers  \
# 0                   Aniplex, Dentsu, YTV, Trinity Sound
# 1     Avex Entertainment, Marvelous, SKY Perfect Wel...
# 2                        Aniplex, Kodansha, Delfi Sound
# 3     Media Factory, AT-X, Sony Music Communications...
# 4                                 TV Tokyo, Pioneer LDC
# ...                                                 ...
# 1995                                Youmex, Toshiba EMI
# 1996                       TBS, Enterbrain, BS-TBS, RAY
# 1997      Bandai Visual, Lantis, Anime Consortium Japan
# 1998                                          AMG MUSIC
# 1999  Media Factory, Bandai, Tohokushinsha Film Corp...
#
#                                  licensors                     studios  \
# 0                         Sentai Filmworks                A-1 Pictures
# 1                               Funimation                     Artland
# 2                       Aniplex of America                     Artland
# 3                               Funimation                   C-Station
# 4     Funimation, Geneon Entertainment USA                         AIC
# ...                                    ...                         ...
# 1995                            Funimation                         AIC
# 1996                      Sentai Filmworks                    Madhouse
# 1997                    Aniplex of America                    ufotable
# 1998                            Funimation                       Zexcs
# 1999                            Funimation  Satelight, Production Reed
#
#             source         duration                          rating  members  \
# 0            Manga  24 min. per ep.       PG-13 - Teens 13 or older   150428
# 1            Manga  25 min. per ep.       PG-13 - Teens 13 or older   620736
# 2            Manga  24 min. per ep.       PG-13 - Teens 13 or older   226522
# 3      Light novel  24 min. per ep.                R+ - Mild Nudity   170220
# 4         Original  23 min. per ep.       PG-13 - Teens 13 or older    62599
# ...            ...              ...                             ...      ...
# 1995      Original  23 min. per ep.                R+ - Mild Nudity    65360
# 1996  Visual novel  23 min. per ep.       PG-13 - Teens 13 or older    93558
# 1997          Game  23 min. per ep.  R - 17+ (violence & profanity)   426616
# 1998   Light novel  24 min. per ep.  R - 17+ (violence & profanity)   178908
# 1999      Original  24 min. per ep.       PG-13 - Teens 13 or older    66799
#
#       watching  completed  on_hold  dropped  plan_to_watch
# 0        16552      37234    13009     6948          76685
# 1        55482     235371    42786    20017         267080
# 2        12585     113559     6095     2606          91677
# 3         8723     118202     3753     8034          31508
# 4         2565      39890     2093     1986          16065
# ...        ...        ...      ...      ...            ...
# 1995      2738      31583     2534     3195          25310
# 1996      6242      45399     3415     8680          29822
# 1997     35000     242285    16731    31573         101027
# 1998      9139     118689     5611     6544          38925
# 1999      2964      36694     2516     3405          21220
#
# [2000 rows x 18 columns]

# %%
# from transformers import GPT2Tokenizer, GPT2Model
from transformers import AutoTokenizer, AutoModel
# tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# model = GPT2Model.from_pretrained('gpt2')
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

text = anime_df["japanese_name"].values[0]
print(text)

inputs = tokenizer(text, return_tensors="pt")


outputs = model(**inputs)

# テキストの埋め込みベクトルを取得
embedding = outputs.last_hidden_state
print(embedding)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 宇宙兄弟
# tensor([[[-0.2126,  0.2585, -0.4528,  ..., -0.3183,  0.7872, -0.0806],
#          [ 0.1778, -0.1561,  0.5393,  ...,  0.1507,  0.6415,  0.2484],
#          [-0.4810, -0.0172,  0.3333,  ..., -0.2040,  0.3433, -0.7411],
#          [-0.2442,  0.3011,  0.2162,  ..., -0.2038,  0.6353, -0.6065],
#          [-0.7008, -0.3108, -0.5303,  ...,  0.2036,  0.5591, -0.9000],
#          [ 0.6575,  0.1178, -0.3368,  ...,  0.1147, -0.5923, -0.2307]]],
#        grad_fn=<NativeLayerNormBackward0>)

# %%
embedding.shape
# Out:
# torch.Size([1, 6, 768])
