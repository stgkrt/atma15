# %%
import os
import io
import pickle
from glob import glob

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from contextlib import contextmanager
from time import time
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
lgb_sub = pd.read_csv("/workspace/working/anime2vec/submission.csv")
svd_sub = pd.read_csv("/workspace/working/svdpp_pred/submission.csv")
gfold_sub = pd.read_csv("/workspace/working/exp014/submission.csv")
xgb_sub = pd.read_csv("/workspace/working/exp008_xgb/submission.csv")

# %%
plt.figure()
plt.hist(lgb_sub.score, alpha=0.2, bins=100, label="lgb")
plt.hist(svd_sub.score, alpha=0.2, bins=100, label="svd")
plt.hist(gfold_sub.score, alpha=0.2, bins=100, label="gfold")
plt.hist(xgb_sub.score, alpha=0.2, bins=100, label="xgb")
plt.legend()
plt.figure()

# %%
sub = (lgb_sub + svd_sub + gfold_sub + xgb_sub) / 4.0

# %%
sub.hist(bins=100)
# Out:
# array([[<Axes: title={'center': 'score'}>]], dtype=object)

# %%
sub
# Out:
#            score
# 0       8.040606
# 1       8.356846
# 2       6.462053
# 3       7.602364
# 4       5.128653
# ...          ...
# 117671  8.360865
# 117672  7.589622
# 117673  7.385161
# 117674  6.999779
# 117675  6.911488
#
# [117676 rows x 1 columns]

# %%
sub.to_csv(os.path.join("/workspace", "working", "4model", "submission.csv"), index=False)
