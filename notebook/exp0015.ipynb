# %%
import os
import io
import pickle
from glob import glob

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from contextlib import contextmanager
from time import time
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error

import wandb
from wandb.lightgbm import wandb_callback, log_summary
import lightgbm as lgb

from sklearn.preprocessing import LabelEncoder

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Config

# %%
EXP_NAME = "exp015"
# EXP_NAME = "debug"

class configs:
    EXP_CATEGORY = "baseline"
    EXP_NAME = EXP_NAME
    OUTPUT_DIR = os.path.join("/workspace", "working", EXP_NAME)
    
    INPUT_DIR = os.path.join("/workspace", "input", "atmaCup15_dataset")
    TRAIN_CSV = os.path.join(INPUT_DIR, "train_stratifiedkfold.csv")
    ANIME_CSV = os.path.join(INPUT_DIR, "anime.csv")
    TEST_CSV = os.path.join(INPUT_DIR, "test.csv")
    SAMPLE_SUB_CSV = os.path.join(INPUT_DIR, "sample_submission.csv")
    target_colname = "score"
    
    W2V_MODEL_PATH = "/workspace/working/word2vec.gensim.model"
    
    COMPETITION = "atmaCup15"
    USER_NAME = "taro"
    wandb_available = True
    
    # train
    num_boost_round = 1000
    early_stopping_rounds = 200
    verbose_eval = 100
    FOLDS = [0, 1, 2, 3, 4]

if EXP_NAME is "debug":
    configs.wandb_available = False
    configs.num_boost_round = 10
else:
    os.makedirs(configs.OUTPUT_DIR)

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    "objective": "rmse", 
    'metric': 'rmse',
    "n_estimators": 10000, 
    "learning_rate": .01,
    "verbosity": -1, 
    "random_state": 510,
}
configs.params = params

# %% [markdown]
# # Utils

# %%
class Timer:
    def __init__(self, logger=None, format_str="{:.3f}[s]", prefix=None, suffix=None, sep=" "):

        if prefix: format_str = str(prefix) + sep + format_str
        if suffix: format_str = format_str + sep + str(suffix)
        self.format_str = format_str
        self.logger = logger
        self.start = None
        self.end = None

    @property
    def duration(self):
        if self.end is None:
            return 0
        return self.end - self.start

    def __enter__(self):
        self.start = time()

    def __exit__(self, exc_type, exc_val, exc_tb):
        self.end = time()
        out_str = self.format_str.format(self.duration)
        if self.logger:
            self.logger.info(out_str)
        else:
            print(out_str)

# %%
def root_mean_squared_error(y_true, y_pred):
    """mean_squared_error の root (0.5乗)"""
    return mean_squared_error(y_true, y_pred) ** .5

# %% [markdown]
# ## utils for data

# %%
def merge_by_anime_id(left_df, right_df):
    return pd.merge(left_df["anime_id"], right_df, on="anime_id", how="left").drop(columns=["anime_id"])

# %% [markdown]
# ## features func

# %%
def create_anime_numeric_feature(input_df: pd.DataFrame):
    """input_dfは train or test.csv のデータが入ってくることを想定しています."""
    
    use_columns = [
        "members", 
    ]
    
    return merge_by_anime_id(input_df, anime_df)[use_columns]

# %% [markdown]
# #### label encoding

# %%
def create_anime_genres_label_encoding(input_df: pd.DataFrame):
    target_col = "genres"
    encoder = LabelEncoder()
    encoded_df = pd.DataFrame({
        "anime_id": anime_df["anime_id"],
        f"{target_col}_le": encoder.fit_transform(anime_df[target_col].fillna("nan"))
    })
    return merge_by_anime_id(input_df, encoded_df)

# %%
def create_anime_source_label_encoding(input_df: pd.DataFrame):
    target_col = "source"
    encoder = LabelEncoder()
    encoded_df = pd.DataFrame({
        "anime_id": anime_df["anime_id"],
        f"{target_col}_le": encoder.fit_transform(anime_df[target_col].fillna("nan"))
    })
    return merge_by_anime_id(input_df, encoded_df)

# %% [markdown]
# #### count encoding

# %%
# animeのtypeをカウントエンコーディング
def create_anime_type_count_encoding(input_df: pd.DataFrame):
    target_col = "type"
    count = anime_df[target_col].map(anime_df["type"].value_counts())
    encoded_df = pd.DataFrame({
        "anime_id": anime_df["anime_id"],
        f"{target_col}_count": count
    })
    
    return merge_by_anime_id(input_df, encoded_df)

# %%
def create_anime_studios_count_encoding(input_df: pd.DataFrame):
    target_col = "studios"
    count = anime_df[target_col].map(anime_df["type"].value_counts())
    encoded_df = pd.DataFrame({
        "anime_id": anime_df["anime_id"],
        f"{target_col}_count": count
    })
    
    return merge_by_anime_id(input_df, encoded_df)

# %%
def create_anime_producers_count_encoding(input_df: pd.DataFrame):
    target_col = "producers"
    count = anime_df[target_col].map(anime_df["type"].value_counts())
    encoded_df = pd.DataFrame({
        "anime_id": anime_df["anime_id"],
        f"{target_col}_count": count
    })
    
    return merge_by_anime_id(input_df, encoded_df)

# %%
def create_anime_animeid_count_encoding(input_df: pd.DataFrame):
    target_col = "anime_id"
    count = anime_df[target_col].map(anime_df["type"].value_counts())
    encoded_df = pd.DataFrame({
        "anime_id": anime_df["anime_id"],
        f"{target_col}_count": count
    })
    
    return merge_by_anime_id(input_df, encoded_df)

# %% [markdown]
# #### one-hot encoding

# %%
# animeのtypeをone-hotエンコーディング
def create_anime_type_one_hot_encoding(input_df: pd.DataFrame):
    # 対象の列のユニーク集合を取る
    target_colname = "type"
    target_series = anime_df[target_colname]
    unique_values = target_series.unique()

    # ユニークな値ごとに列を作る
    out_df = pd.DataFrame()
    for value in unique_values:
        is_value = target_series == value
        if value == "Unknown":
            out_df["Unknown_type"] = is_value.astype(int)
        else:
            out_df[value] = is_value.astype(int)
    
    out_df["anime_id"] = anime_df["anime_id"]
    return merge_by_anime_id(input_df, out_df)

# %%
# animeのtypeをone-hotエンコーディング
def create_anime_rating_one_hot_encoding(input_df: pd.DataFrame):
    # 対象の列のユニーク集合を取る
    target_colname = "rating"
    target_series = anime_df[target_colname]
    unique_values = target_series.unique()

    # ユニークな値ごとに列を作る
    out_df = pd.DataFrame()
    for value in unique_values:
        is_value = target_series == value
        if value == "Unknown":
            out_df["Unknown_rate"] = is_value.astype(int)
        else:
            out_df[value] = is_value.astype(int)
    
    out_df["anime_id"] = anime_df["anime_id"]
    return merge_by_anime_id(input_df, out_df)

# %% [markdown]
# ### word to vec

# %%
def word2vec(word):
    try:
        return w2v.wv[word]
    except KeyError:
        return None


def doc2vectors(doc: str):
    words = separate_to_words(doc=doc)

    embeddings = [word2vec(w) for w in words]
    embeddings = [emb for emb in embeddings if emb is not None]
    embeddings = np.array(embeddings)

    if len(embeddings) == 0:
        print(f"- {doc}: 語彙にありませんでした.")
        return np.zeros(shape=(50,))

    # 単語ごとに要素の max を取る
    return np.max(embeddings, axis=0)

def separate_to_words(doc: str):
    """文章を単語の配列に変換する"""

    parsed_str = tagger.parse(doc).strip()
    return parsed_str.split(" ")


def create_anime_title_embedding_feature(input_df):
    # 予め作っておいた特徴量を
    embedding_df = pd.DataFrame(anime_name_vector_df.values, index=anime_df["anime_id"])

    # 入力されたデータに紐付けて
    out_df = merge_by_anime_id(input_df, embedding_df)

    # prefix を付けて返す
    return out_df.add_prefix("name_w2v_")

# %%
# 上で定義した関数をまとめて実行
def create_feature(input_df, config_):
    # functions に特徴量作成関数を配列で定義しました.
    # どの関数も同じ input / output のインターフェイスなので for で回せて嬉しいですね ;)
    functions = [
        create_anime_numeric_feature,
        # label encoding
        create_anime_genres_label_encoding, 
        create_anime_source_label_encoding, 
        # count encoding
        create_anime_type_count_encoding,
        create_anime_studios_count_encoding,
        create_anime_producers_count_encoding,
        create_anime_animeid_count_encoding, 
        # one-hot encoding
        create_anime_type_one_hot_encoding,
        create_anime_rating_one_hot_encoding,
    ]
    
    out_df = pd.DataFrame()
    func_name_list = []
    for func in functions:
        func_name = str(func.__name__)
        func_name_list.append(func_name)
        with Timer(prefix=f"create {func_name}"):
            _df = func(input_df)
        out_df = pd.concat([out_df, _df], axis=1)
    
    config_.preprocess_funcs = func_name_list
    return out_df, config_

# %% [markdown]
# # train func

# %%
def save_model(model, fold):
    save_path = os.path.join(configs.OUTPUT_DIR, f"model_fold{fold}.pkl")
    # pickle.dump(model, save_path)
    with open(save_path, 'wb') as f:
        pickle.dump(model, f)
    print(f"SAVED: {save_path}")

# %%
def fit_lgbm(df, configs):
    """lightGBM を CrossValidation の枠組みで学習を行なう function"""

    models = []
    evals_results_list = [] 
    n_records = len(df)
    # training data の target と同じだけのゼロ配列を用意
    oof_pred = np.zeros((n_records, ), dtype=np.float32)
    target = []
    for fold in configs.FOLDS: 
        # この部分が交差検証のところです。データセットを cv instance によって分割します
        # training data を trian/valid に分割
        train_df_ = df[df["fold"] != fold].reset_index(drop=True)
        valid_df_ = df[df["fold"] == fold].reset_index(drop=True)
        idx_valid = df[df["fold"] == fold].index.values
        
        x_train = train_df_.drop(columns=[configs.target_colname, "fold"])
        # print(x_train.columns)
        y_train = train_df_[configs.target_colname]
        x_valid = valid_df_.drop(columns=[configs.target_colname, "fold"])
        y_valid = valid_df_[configs.target_colname]
        target.extend(y_valid)
        
        lgb_train = lgb.Dataset(x_train, y_train)
        lgb_eval = lgb.Dataset(x_valid, y_valid, reference=lgb_train)

        lgb_result = {}
        with Timer(prefix="fit fold={} ".format(fold)):
            if configs.wandb_available:
                clf = lgb.train(configs.params,
                                lgb_train,
                                valid_sets=[lgb_train, lgb_eval],  
                                valid_names=[f"validation_{fold}"],
                                num_boost_round=configs.num_boost_round,
                                early_stopping_rounds=configs.early_stopping_rounds,
                                evals_result=lgb_result,
                                verbose_eval=configs.verbose_eval,
                                callbacks=[wandb_callback()])
                evals_results_list.append(lgb_result)
                log_summary(clf, save_model_checkpoint=False)

            else:
                clf = lgb.train(configs.params,
                                lgb_train,
                                valid_sets=[lgb_train, lgb_eval],  
                                valid_names=[f"validation_{fold}"],
                                num_boost_round=configs.num_boost_round,
                                early_stopping_rounds=configs.early_stopping_rounds,
                                evals_result=lgb_result,
                                verbose_eval=configs.verbose_eval,
                                )
                evals_results_list.append(lgb_result)
        
        # cv 内で validation data とされた x_valid で予測をして oof_pred に保存していく
        # oof_pred は全部学習に使わなかったデータの予測結果になる → モデルの予測性能を見る指標として利用できる
        pred_i = clf.predict(x_valid)
        oof_pred[idx_valid] = pred_i
        models.append(clf)
        save_model(clf, fold)
        score = root_mean_squared_error(y_valid, pred_i)
        print(f" - fold{fold} - {score:.4f}")
        if configs.wandb_available:
            wandb.log({"fold": fold, "rmse": score})

    score = root_mean_squared_error(target, oof_pred)

    print("=" * 50)
    print(f"FINISHI: Whole Score: {score:.4f}")
    return oof_pred, target, models, evals_results_list

# %% [markdown]
# # Load data

# %%
anime_df = pd.read_csv(configs.ANIME_CSV)

train_df = pd.read_csv(configs.TRAIN_CSV)
test_df = pd.read_csv(configs.TEST_CSV)

# %% [markdown]
# ## preprocess
# - CountEncoding
# - OneHotEncoding

# %%
# 実行して train / test 用の特徴量を作ります.

with Timer(prefix="train..."):
    train_feat_df, configs = create_feature(train_df, configs)

with Timer(prefix="test..."):
    test_feat_df, configs = create_feature(test_df, configs)

# X = train_feat_df.values
# print(train_feat_df.columns)
# y = train_df["score"].values
# Out:
# create create_anime_numeric_feature 0.059[s]
# create create_anime_genres_label_encoding 0.013[s]
# create create_anime_source_label_encoding 0.010[s]
# create create_anime_type_count_encoding 0.010[s]
# create create_anime_studios_count_encoding 0.010[s]
# create create_anime_producers_count_encoding 0.011[s]
# create create_anime_animeid_count_encoding 0.010[s]
# create create_anime_type_one_hot_encoding 0.015[s]
# create create_anime_rating_one_hot_encoding 0.015[s]
# train... 0.163[s]
# create create_anime_numeric_feature 0.040[s]
# create create_anime_genres_label_encoding 0.011[s]
# create create_anime_source_label_encoding 0.011[s]
# create create_anime_type_count_encoding 0.011[s]
# create create_anime_studios_count_encoding 0.009[s]
# create create_anime_producers_count_encoding 0.010[s]
# create create_anime_animeid_count_encoding 0.010[s]
# create create_anime_type_one_hot_encoding 0.014[s]
# create create_anime_rating_one_hot_encoding 0.013[s]
# test... 0.138[s]

# %%
input_df = pd.concat([train_df, train_feat_df], axis=1)
input_df = input_df.drop(["user_id", "anime_id"], axis=1)

# %%
input_df.columns
# Out:
# Index(['score', 'fold', 'members', 'genres_le', 'source_le', 'type_count',
#        'studios_count', 'producers_count', 'anime_id_count', 'TV', 'Special',
#        'Movie', 'Unknown_type', 'ONA', 'OVA', 'Music',
#        'PG-13 - Teens 13 or older', 'R+ - Mild Nudity',
#        'R - 17+ (violence & profanity)', 'G - All Ages', 'PG - Children',
#        'Rx - Hentai', 'Unknown_rate'],
#       dtype='object')

# %% [markdown]
# # Train

# %%
if configs.wandb_available:
   WANDB_CONFIG = {'competition': "atma15", '_wandb_kernel': "taro"}
   os.environ["WANDB_SILENT"] = "true"
   # config_dict = dict(vars(configs))
   wandb.init(project=WANDB_CONFIG["competition"],
               # config=config_dict,
               group=configs.EXP_CATEGORY, 
               name=configs.EXP_NAME,
               reinit=True,
               save_code=True)
   print("wandb initialized")
else:
   print("wandb logging is not available")
# Out:
# wandb initialized

# %%
oof, target, models, evals_results = fit_lgbm(input_df, configs)
# Out:
# Training until validation scores don't improve for 200 rounds
# [100]	validation_0's rmse: 1.50193	valid_1's rmse: 1.50689
# [200]	validation_0's rmse: 1.48148	valid_1's rmse: 1.48947
# [300]	validation_0's rmse: 1.46988	valid_1's rmse: 1.47991
# [400]	validation_0's rmse: 1.46249	valid_1's rmse: 1.4738
# [500]	validation_0's rmse: 1.45711	valid_1's rmse: 1.46958
# [600]	validation_0's rmse: 1.45271	valid_1's rmse: 1.46613
# [700]	validation_0's rmse: 1.4492	valid_1's rmse: 1.46337
# [800]	validation_0's rmse: 1.44641	valid_1's rmse: 1.46117
# [900]	validation_0's rmse: 1.44379	valid_1's rmse: 1.45918
# [1000]	validation_0's rmse: 1.44152	valid_1's rmse: 1.45737
# [1100]	validation_0's rmse: 1.43933	valid_1's rmse: 1.45551
# [1200]	validation_0's rmse: 1.43725	valid_1's rmse: 1.45389
# [1300]	validation_0's rmse: 1.43545	valid_1's rmse: 1.45249
# [1400]	validation_0's rmse: 1.43363	valid_1's rmse: 1.4509
# [1500]	validation_0's rmse: 1.43194	valid_1's rmse: 1.44954
# [1600]	validation_0's rmse: 1.43049	valid_1's rmse: 1.44843
# [1700]	validation_0's rmse: 1.42927	valid_1's rmse: 1.44752
# [1800]	validation_0's rmse: 1.42812	valid_1's rmse: 1.4467
# [1900]	validation_0's rmse: 1.42691	valid_1's rmse: 1.44585
# [2000]	validation_0's rmse: 1.42578	valid_1's rmse: 1.44497
# [2100]	validation_0's rmse: 1.42471	valid_1's rmse: 1.44421
# [2200]	validation_0's rmse: 1.42368	valid_1's rmse: 1.44342
# [2300]	validation_0's rmse: 1.42274	valid_1's rmse: 1.44277
# [2400]	validation_0's rmse: 1.42191	valid_1's rmse: 1.44221
# [2500]	validation_0's rmse: 1.42106	valid_1's rmse: 1.44162
# [2600]	validation_0's rmse: 1.42026	valid_1's rmse: 1.44111
# [2700]	validation_0's rmse: 1.41965	valid_1's rmse: 1.44073
# [2800]	validation_0's rmse: 1.41908	valid_1's rmse: 1.4404
# [2900]	validation_0's rmse: 1.41856	valid_1's rmse: 1.44007
# [3000]	validation_0's rmse: 1.41803	valid_1's rmse: 1.43974
# [3100]	validation_0's rmse: 1.41753	valid_1's rmse: 1.43947
# [3200]	validation_0's rmse: 1.41706	valid_1's rmse: 1.43919
# [3300]	validation_0's rmse: 1.4166	valid_1's rmse: 1.43896
# [3400]	validation_0's rmse: 1.41615	valid_1's rmse: 1.43876
# [3500]	validation_0's rmse: 1.41576	valid_1's rmse: 1.43857
# [3600]	validation_0's rmse: 1.41539	valid_1's rmse: 1.43837
# [3700]	validation_0's rmse: 1.41507	valid_1's rmse: 1.43822
# [3800]	validation_0's rmse: 1.41474	valid_1's rmse: 1.43808
# [3900]	validation_0's rmse: 1.41444	valid_1's rmse: 1.43792
# [4000]	validation_0's rmse: 1.41406	valid_1's rmse: 1.43772
# [4100]	validation_0's rmse: 1.41373	valid_1's rmse: 1.43754
# [4200]	validation_0's rmse: 1.41345	valid_1's rmse: 1.43736
# [4300]	validation_0's rmse: 1.41317	valid_1's rmse: 1.43724
# [4400]	validation_0's rmse: 1.41294	valid_1's rmse: 1.43713
# [4500]	validation_0's rmse: 1.4127	valid_1's rmse: 1.437
# [4600]	validation_0's rmse: 1.41248	valid_1's rmse: 1.43685
# [4700]	validation_0's rmse: 1.41227	valid_1's rmse: 1.43673
# [4800]	validation_0's rmse: 1.41209	valid_1's rmse: 1.43667
# [4900]	validation_0's rmse: 1.41183	valid_1's rmse: 1.43657
# [5000]	validation_0's rmse: 1.4116	valid_1's rmse: 1.43649
# [5100]	validation_0's rmse: 1.41137	valid_1's rmse: 1.43641
# [5200]	validation_0's rmse: 1.41118	valid_1's rmse: 1.43632
# [5300]	validation_0's rmse: 1.41103	valid_1's rmse: 1.43623
# [5400]	validation_0's rmse: 1.41089	valid_1's rmse: 1.43615
# [5500]	validation_0's rmse: 1.41074	valid_1's rmse: 1.43609
# [5600]	validation_0's rmse: 1.41059	valid_1's rmse: 1.43606
# [5700]	validation_0's rmse: 1.41046	valid_1's rmse: 1.43603
# [5800]	validation_0's rmse: 1.41034	valid_1's rmse: 1.436
# [5900]	validation_0's rmse: 1.41021	valid_1's rmse: 1.43595
# [6000]	validation_0's rmse: 1.4101	valid_1's rmse: 1.4359
# [6100]	validation_0's rmse: 1.40999	valid_1's rmse: 1.43584
# [6200]	validation_0's rmse: 1.40989	valid_1's rmse: 1.43577
# [6300]	validation_0's rmse: 1.40981	valid_1's rmse: 1.43575
# [6400]	validation_0's rmse: 1.40972	valid_1's rmse: 1.43573
# [6500]	validation_0's rmse: 1.40962	valid_1's rmse: 1.43571
# [6600]	validation_0's rmse: 1.40954	valid_1's rmse: 1.43568
# [6700]	validation_0's rmse: 1.40946	valid_1's rmse: 1.43566
# [6800]	validation_0's rmse: 1.4094	valid_1's rmse: 1.43566
# [6900]	validation_0's rmse: 1.40932	valid_1's rmse: 1.43562
# [7000]	validation_0's rmse: 1.40924	valid_1's rmse: 1.43558
# [7100]	validation_0's rmse: 1.40917	valid_1's rmse: 1.43554
# [7200]	validation_0's rmse: 1.40911	valid_1's rmse: 1.43554
# [7300]	validation_0's rmse: 1.40906	valid_1's rmse: 1.43554
# Early stopping, best iteration is:
# [7150]	validation_0's rmse: 1.40914	valid_1's rmse: 1.43553
# fit fold=0  88.846[s]
# SAVED: /workspace/working/exp015/model_fold0.pkl
#  - fold0 - 1.4355
# Training until validation scores don't improve for 200 rounds
# [100]	validation_1's rmse: 1.50345	valid_1's rmse: 1.50238
# [200]	validation_1's rmse: 1.48377	valid_1's rmse: 1.48334
# [300]	validation_1's rmse: 1.47229	valid_1's rmse: 1.47273
# [400]	validation_1's rmse: 1.46518	valid_1's rmse: 1.46656
# [500]	validation_1's rmse: 1.46001	valid_1's rmse: 1.46207
# [600]	validation_1's rmse: 1.45575	valid_1's rmse: 1.45852
# [700]	validation_1's rmse: 1.45171	valid_1's rmse: 1.45539
# [800]	validation_1's rmse: 1.44819	valid_1's rmse: 1.45272
# [900]	validation_1's rmse: 1.44528	valid_1's rmse: 1.45048
# [1000]	validation_1's rmse: 1.44294	valid_1's rmse: 1.44867
# [1100]	validation_1's rmse: 1.44065	valid_1's rmse: 1.44706
# [1200]	validation_1's rmse: 1.43858	valid_1's rmse: 1.44553
# [1300]	validation_1's rmse: 1.43672	valid_1's rmse: 1.44418
# [1400]	validation_1's rmse: 1.43513	valid_1's rmse: 1.44308
# [1500]	validation_1's rmse: 1.43338	valid_1's rmse: 1.44176
# [1600]	validation_1's rmse: 1.43198	valid_1's rmse: 1.44074
# [1700]	validation_1's rmse: 1.43055	valid_1's rmse: 1.43974
# [1800]	validation_1's rmse: 1.42923	valid_1's rmse: 1.43879
# [1900]	validation_1's rmse: 1.42802	valid_1's rmse: 1.43795
# [2000]	validation_1's rmse: 1.4268	valid_1's rmse: 1.4371
# [2100]	validation_1's rmse: 1.42578	valid_1's rmse: 1.43642
# [2200]	validation_1's rmse: 1.42479	valid_1's rmse: 1.43584
# [2300]	validation_1's rmse: 1.42387	valid_1's rmse: 1.43519
# [2400]	validation_1's rmse: 1.42303	valid_1's rmse: 1.43475
# [2500]	validation_1's rmse: 1.4222	valid_1's rmse: 1.43421
# [2600]	validation_1's rmse: 1.42143	valid_1's rmse: 1.43374
# [2700]	validation_1's rmse: 1.42069	valid_1's rmse: 1.43333
# [2800]	validation_1's rmse: 1.42005	valid_1's rmse: 1.43302
# [2900]	validation_1's rmse: 1.41945	valid_1's rmse: 1.43271
# [3000]	validation_1's rmse: 1.41894	valid_1's rmse: 1.43245
# [3100]	validation_1's rmse: 1.41845	valid_1's rmse: 1.43214
# [3200]	validation_1's rmse: 1.41803	valid_1's rmse: 1.43198
# [3300]	validation_1's rmse: 1.41755	valid_1's rmse: 1.43173
# [3400]	validation_1's rmse: 1.41704	valid_1's rmse: 1.43136
# [3500]	validation_1's rmse: 1.41664	valid_1's rmse: 1.4311
# [3600]	validation_1's rmse: 1.41626	valid_1's rmse: 1.43086
# [3700]	validation_1's rmse: 1.41588	valid_1's rmse: 1.43068
# [3800]	validation_1's rmse: 1.41555	valid_1's rmse: 1.4305
# [3900]	validation_1's rmse: 1.41522	valid_1's rmse: 1.43037
# [4000]	validation_1's rmse: 1.41493	valid_1's rmse: 1.43023
# [4100]	validation_1's rmse: 1.41464	valid_1's rmse: 1.43009
# [4200]	validation_1's rmse: 1.41437	valid_1's rmse: 1.43002
# [4300]	validation_1's rmse: 1.4141	valid_1's rmse: 1.42988
# [4400]	validation_1's rmse: 1.41389	valid_1's rmse: 1.42981
# [4500]	validation_1's rmse: 1.41365	valid_1's rmse: 1.42968
# [4600]	validation_1's rmse: 1.41346	valid_1's rmse: 1.42962
# [4700]	validation_1's rmse: 1.41328	valid_1's rmse: 1.42957
# [4800]	validation_1's rmse: 1.41309	valid_1's rmse: 1.42947
# [4900]	validation_1's rmse: 1.41287	valid_1's rmse: 1.42935
# [5000]	validation_1's rmse: 1.41266	valid_1's rmse: 1.42929
# [5100]	validation_1's rmse: 1.4125	valid_1's rmse: 1.42927
# [5200]	validation_1's rmse: 1.41232	valid_1's rmse: 1.42921
# [5300]	validation_1's rmse: 1.41216	valid_1's rmse: 1.42915
# [5400]	validation_1's rmse: 1.41202	valid_1's rmse: 1.42911
# [5500]	validation_1's rmse: 1.4119	valid_1's rmse: 1.42909
# [5600]	validation_1's rmse: 1.41179	valid_1's rmse: 1.42907
# [5700]	validation_1's rmse: 1.41167	valid_1's rmse: 1.42906
# [5800]	validation_1's rmse: 1.41157	valid_1's rmse: 1.42904
# [5900]	validation_1's rmse: 1.41147	valid_1's rmse: 1.42901
# [6000]	validation_1's rmse: 1.41136	valid_1's rmse: 1.42898
# [6100]	validation_1's rmse: 1.41128	valid_1's rmse: 1.429
# [6200]	validation_1's rmse: 1.4112	valid_1's rmse: 1.42901
# Early stopping, best iteration is:
# [6016]	validation_1's rmse: 1.41135	valid_1's rmse: 1.42898
# fit fold=1  84.251[s]
# SAVED: /workspace/working/exp015/model_fold1.pkl
#  - fold1 - 1.4290
# Training until validation scores don't improve for 200 rounds
# [100]	validation_2's rmse: 1.50384	valid_1's rmse: 1.50246
# [200]	validation_2's rmse: 1.48349	valid_1's rmse: 1.48276
# [300]	validation_2's rmse: 1.47208	valid_1's rmse: 1.47185
# [400]	validation_2's rmse: 1.4649	valid_1's rmse: 1.46541
# [500]	validation_2's rmse: 1.45981	valid_1's rmse: 1.46108
# [600]	validation_2's rmse: 1.45539	valid_1's rmse: 1.4573
# [700]	validation_2's rmse: 1.45186	valid_1's rmse: 1.4544
# [800]	validation_2's rmse: 1.44867	valid_1's rmse: 1.45201
# [900]	validation_2's rmse: 1.44589	valid_1's rmse: 1.45002
# [1000]	validation_2's rmse: 1.44346	valid_1's rmse: 1.44822
# [1100]	validation_2's rmse: 1.44122	valid_1's rmse: 1.4465
# [1200]	validation_2's rmse: 1.43922	valid_1's rmse: 1.4451
# [1300]	validation_2's rmse: 1.43743	valid_1's rmse: 1.44382
# [1400]	validation_2's rmse: 1.43574	valid_1's rmse: 1.4426
# [1500]	validation_2's rmse: 1.43392	valid_1's rmse: 1.4412
# [1600]	validation_2's rmse: 1.43245	valid_1's rmse: 1.44013
# [1700]	validation_2's rmse: 1.431	valid_1's rmse: 1.43906
# [1800]	validation_2's rmse: 1.42973	valid_1's rmse: 1.43811
# [1900]	validation_2's rmse: 1.42872	valid_1's rmse: 1.43732
# [2000]	validation_2's rmse: 1.42773	valid_1's rmse: 1.43663
# [2100]	validation_2's rmse: 1.42672	valid_1's rmse: 1.43598
# [2200]	validation_2's rmse: 1.42575	valid_1's rmse: 1.43544
# [2300]	validation_2's rmse: 1.42484	valid_1's rmse: 1.43492
# [2400]	validation_2's rmse: 1.42401	valid_1's rmse: 1.43438
# [2500]	validation_2's rmse: 1.4232	valid_1's rmse: 1.4339
# [2600]	validation_2's rmse: 1.42245	valid_1's rmse: 1.43341
# [2700]	validation_2's rmse: 1.42179	valid_1's rmse: 1.43297
# [2800]	validation_2's rmse: 1.42114	valid_1's rmse: 1.43254
# [2900]	validation_2's rmse: 1.42048	valid_1's rmse: 1.43217
# [3000]	validation_2's rmse: 1.41985	valid_1's rmse: 1.43185
# [3100]	validation_2's rmse: 1.41934	valid_1's rmse: 1.43154
# [3200]	validation_2's rmse: 1.41888	valid_1's rmse: 1.43133
# [3300]	validation_2's rmse: 1.41844	valid_1's rmse: 1.43109
# [3400]	validation_2's rmse: 1.418	valid_1's rmse: 1.43089
# [3500]	validation_2's rmse: 1.41759	valid_1's rmse: 1.43072
# [3600]	validation_2's rmse: 1.41711	valid_1's rmse: 1.43058
# [3700]	validation_2's rmse: 1.4167	valid_1's rmse: 1.43045
# [3800]	validation_2's rmse: 1.41637	valid_1's rmse: 1.4303
# [3900]	validation_2's rmse: 1.41601	valid_1's rmse: 1.43016
# [4000]	validation_2's rmse: 1.4157	valid_1's rmse: 1.43006
# [4100]	validation_2's rmse: 1.41538	valid_1's rmse: 1.42997
# [4200]	validation_2's rmse: 1.41509	valid_1's rmse: 1.42991
# [4300]	validation_2's rmse: 1.41483	valid_1's rmse: 1.42979
# [4400]	validation_2's rmse: 1.4146	valid_1's rmse: 1.42971
# [4500]	validation_2's rmse: 1.41441	valid_1's rmse: 1.42967
# [4600]	validation_2's rmse: 1.41418	valid_1's rmse: 1.42962
# [4700]	validation_2's rmse: 1.41395	valid_1's rmse: 1.42955
# [4800]	validation_2's rmse: 1.41373	valid_1's rmse: 1.42949
# [4900]	validation_2's rmse: 1.41353	valid_1's rmse: 1.42942
# [5000]	validation_2's rmse: 1.41336	valid_1's rmse: 1.42939
# [5100]	validation_2's rmse: 1.41316	valid_1's rmse: 1.42933
# [5200]	validation_2's rmse: 1.41296	valid_1's rmse: 1.42924
# [5300]	validation_2's rmse: 1.41275	valid_1's rmse: 1.42911
# [5400]	validation_2's rmse: 1.41257	valid_1's rmse: 1.42902
# [5500]	validation_2's rmse: 1.41243	valid_1's rmse: 1.42904
# [5600]	validation_2's rmse: 1.4123	valid_1's rmse: 1.42906
# Early stopping, best iteration is:
# [5402]	validation_2's rmse: 1.41257	valid_1's rmse: 1.42902
# fit fold=2  76.062[s]
# SAVED: /workspace/working/exp015/model_fold2.pkl
#  - fold2 - 1.4290
# Training until validation scores don't improve for 200 rounds
# [100]	validation_3's rmse: 1.50263	valid_1's rmse: 1.50641
# [200]	validation_3's rmse: 1.48239	valid_1's rmse: 1.48678
# [300]	validation_3's rmse: 1.47172	valid_1's rmse: 1.4767
# [400]	validation_3's rmse: 1.4643	valid_1's rmse: 1.47019
# [500]	validation_3's rmse: 1.45906	valid_1's rmse: 1.46576
# [600]	validation_3's rmse: 1.45449	valid_1's rmse: 1.46197
# [700]	validation_3's rmse: 1.45065	valid_1's rmse: 1.4588
# [800]	validation_3's rmse: 1.44753	valid_1's rmse: 1.45639
# [900]	validation_3's rmse: 1.44479	valid_1's rmse: 1.45413
# [1000]	validation_3's rmse: 1.44246	valid_1's rmse: 1.45234
# [1100]	validation_3's rmse: 1.44048	valid_1's rmse: 1.4509
# [1200]	validation_3's rmse: 1.43845	valid_1's rmse: 1.44928
# [1300]	validation_3's rmse: 1.43652	valid_1's rmse: 1.44773
# [1400]	validation_3's rmse: 1.43477	valid_1's rmse: 1.44628
# [1500]	validation_3's rmse: 1.43357	valid_1's rmse: 1.44547
# [1600]	validation_3's rmse: 1.43229	valid_1's rmse: 1.44461
# [1700]	validation_3's rmse: 1.43083	valid_1's rmse: 1.44348
# [1800]	validation_3's rmse: 1.4294	valid_1's rmse: 1.44234
# [1900]	validation_3's rmse: 1.42818	valid_1's rmse: 1.44155
# [2000]	validation_3's rmse: 1.42701	valid_1's rmse: 1.44076
# [2100]	validation_3's rmse: 1.42598	valid_1's rmse: 1.44011
# [2200]	validation_3's rmse: 1.42498	valid_1's rmse: 1.4395
# [2300]	validation_3's rmse: 1.42403	valid_1's rmse: 1.43892
# [2400]	validation_3's rmse: 1.4231	valid_1's rmse: 1.43839
# [2500]	validation_3's rmse: 1.42224	valid_1's rmse: 1.43797
# [2600]	validation_3's rmse: 1.42144	valid_1's rmse: 1.43754
# [2700]	validation_3's rmse: 1.42072	valid_1's rmse: 1.43709
# [2800]	validation_3's rmse: 1.42006	valid_1's rmse: 1.43681
# [2900]	validation_3's rmse: 1.41945	valid_1's rmse: 1.43651
# [3000]	validation_3's rmse: 1.41881	valid_1's rmse: 1.43605
# [3100]	validation_3's rmse: 1.41833	valid_1's rmse: 1.43572
# [3200]	validation_3's rmse: 1.41785	valid_1's rmse: 1.4354
# [3300]	validation_3's rmse: 1.41741	valid_1's rmse: 1.43516
# [3400]	validation_3's rmse: 1.41699	valid_1's rmse: 1.43498
# [3500]	validation_3's rmse: 1.41657	valid_1's rmse: 1.43477
# [3600]	validation_3's rmse: 1.41618	valid_1's rmse: 1.43452
# [3700]	validation_3's rmse: 1.41579	valid_1's rmse: 1.43435
# [3800]	validation_3's rmse: 1.4154	valid_1's rmse: 1.43408
# [3900]	validation_3's rmse: 1.41503	valid_1's rmse: 1.43387
# [4000]	validation_3's rmse: 1.41468	valid_1's rmse: 1.43368
# [4100]	validation_3's rmse: 1.4143	valid_1's rmse: 1.43352
# [4200]	validation_3's rmse: 1.41401	valid_1's rmse: 1.43343
# [4300]	validation_3's rmse: 1.41369	valid_1's rmse: 1.43324
# [4400]	validation_3's rmse: 1.41342	valid_1's rmse: 1.43312
# [4500]	validation_3's rmse: 1.41321	valid_1's rmse: 1.43302
# [4600]	validation_3's rmse: 1.413	valid_1's rmse: 1.43293
# [4700]	validation_3's rmse: 1.41279	valid_1's rmse: 1.43284
# [4800]	validation_3's rmse: 1.41258	valid_1's rmse: 1.43277
# [4900]	validation_3's rmse: 1.41242	valid_1's rmse: 1.43269
# [5000]	validation_3's rmse: 1.41224	valid_1's rmse: 1.43262
# [5100]	validation_3's rmse: 1.41204	valid_1's rmse: 1.43257
# [5200]	validation_3's rmse: 1.41187	valid_1's rmse: 1.43254
# [5300]	validation_3's rmse: 1.41169	valid_1's rmse: 1.43247
# [5400]	validation_3's rmse: 1.41152	valid_1's rmse: 1.43244
# [5500]	validation_3's rmse: 1.41138	valid_1's rmse: 1.43242
# [5600]	validation_3's rmse: 1.41126	valid_1's rmse: 1.43242
# [5700]	validation_3's rmse: 1.41114	valid_1's rmse: 1.43242
# Early stopping, best iteration is:
# [5518]	validation_3's rmse: 1.41136	valid_1's rmse: 1.43241
# fit fold=3  73.880[s]
# SAVED: /workspace/working/exp015/model_fold3.pkl
#  - fold3 - 1.4324
# Training until validation scores don't improve for 200 rounds
# [100]	validation_4's rmse: 1.50271	valid_1's rmse: 1.50507
# [200]	validation_4's rmse: 1.4817	valid_1's rmse: 1.48599
# [300]	validation_4's rmse: 1.47048	valid_1's rmse: 1.47603
# [400]	validation_4's rmse: 1.46316	valid_1's rmse: 1.47036
# [500]	validation_4's rmse: 1.45778	valid_1's rmse: 1.46641
# [600]	validation_4's rmse: 1.45348	valid_1's rmse: 1.46309
# [700]	validation_4's rmse: 1.44999	valid_1's rmse: 1.46061
# [800]	validation_4's rmse: 1.44702	valid_1's rmse: 1.45839
# [900]	validation_4's rmse: 1.44411	valid_1's rmse: 1.4565
# [1000]	validation_4's rmse: 1.4415	valid_1's rmse: 1.45474
# [1100]	validation_4's rmse: 1.43923	valid_1's rmse: 1.4533
# [1200]	validation_4's rmse: 1.4371	valid_1's rmse: 1.45208
# [1300]	validation_4's rmse: 1.43528	valid_1's rmse: 1.45108
# [1400]	validation_4's rmse: 1.43343	valid_1's rmse: 1.44992
# [1500]	validation_4's rmse: 1.43168	valid_1's rmse: 1.44881
# [1600]	validation_4's rmse: 1.42994	valid_1's rmse: 1.44778
# [1700]	validation_4's rmse: 1.42844	valid_1's rmse: 1.44691
# [1800]	validation_4's rmse: 1.42712	valid_1's rmse: 1.44619
# [1900]	validation_4's rmse: 1.42592	valid_1's rmse: 1.44548
# [2000]	validation_4's rmse: 1.42479	valid_1's rmse: 1.44487
# [2100]	validation_4's rmse: 1.42382	valid_1's rmse: 1.44449
# [2200]	validation_4's rmse: 1.42294	valid_1's rmse: 1.44411
# [2300]	validation_4's rmse: 1.42222	valid_1's rmse: 1.44378
# [2400]	validation_4's rmse: 1.42139	valid_1's rmse: 1.44329
# [2500]	validation_4's rmse: 1.42069	valid_1's rmse: 1.44283
# [2600]	validation_4's rmse: 1.42007	valid_1's rmse: 1.44249
# [2700]	validation_4's rmse: 1.41944	valid_1's rmse: 1.44221
# [2800]	validation_4's rmse: 1.41884	valid_1's rmse: 1.44195
# [2900]	validation_4's rmse: 1.41817	valid_1's rmse: 1.4416
# [3000]	validation_4's rmse: 1.41762	valid_1's rmse: 1.44132
# [3100]	validation_4's rmse: 1.41714	valid_1's rmse: 1.44109
# [3200]	validation_4's rmse: 1.41657	valid_1's rmse: 1.44076
# [3300]	validation_4's rmse: 1.41604	valid_1's rmse: 1.44055
# [3400]	validation_4's rmse: 1.41554	valid_1's rmse: 1.44026
# [3500]	validation_4's rmse: 1.41511	valid_1's rmse: 1.44001
# [3600]	validation_4's rmse: 1.41469	valid_1's rmse: 1.43986
# [3700]	validation_4's rmse: 1.41429	valid_1's rmse: 1.43974
# [3800]	validation_4's rmse: 1.41387	valid_1's rmse: 1.43961
# [3900]	validation_4's rmse: 1.41354	valid_1's rmse: 1.43948
# [4000]	validation_4's rmse: 1.41325	valid_1's rmse: 1.43936
# [4100]	validation_4's rmse: 1.41299	valid_1's rmse: 1.43926
# [4200]	validation_4's rmse: 1.41271	valid_1's rmse: 1.43914
# [4300]	validation_4's rmse: 1.41244	valid_1's rmse: 1.43905
# [4400]	validation_4's rmse: 1.4122	valid_1's rmse: 1.43903
# [4500]	validation_4's rmse: 1.41194	valid_1's rmse: 1.43894
# [4600]	validation_4's rmse: 1.41168	valid_1's rmse: 1.43892
# [4700]	validation_4's rmse: 1.41148	valid_1's rmse: 1.43893
# Early stopping, best iteration is:
# [4585]	validation_4's rmse: 1.41171	valid_1's rmse: 1.43891
# fit fold=4  69.451[s]
# SAVED: /workspace/working/exp015/model_fold4.pkl
#  - fold4 - 1.4389
# ==================================================
# FINISHI: Whole Score: 1.6864

# %%
for evals in evals_results:
    lgb.plot_metric(evals, metric="rmse")

# %% [markdown]
# # Result

# %%
oof_score = root_mean_squared_error(y_true=target, y_pred=oof)
print(oof_score)
# Out:
# 1.6864456778032515

# %% [markdown]
# ### result distribution

# %%
fig, ax = plt.subplots(figsize=(8, 8))

sns.boxenplot(data=pd.DataFrame({ "GroundTruth": target, "OutOfFold Prediction": oof }), 
              x="GroundTruth", y="OutOfFold Prediction", ax=ax)

ax.grid()
ax.plot([0, 9], [1, 10], "--", c="black", alpha=.2)

# %% [markdown]
# ### result importance

# %%
for idx, model in enumerate(models):
    lgb.plot_importance(model, figsize=(5,5),
                        importance_type="gain", max_num_features=25, 
                        xlabel="Feature Importance", ylabel="Features")

# %% [markdown]
# # Inference

# %% [markdown]
# ['svd', 'members', 'tyoe_count', 'TV', 'Special', 'Movie', 'Unknown','ONA', 'OVA', 'Music']

# %%
input_columns = [col for col in input_df.columns if col not in ["fold", "score"]]
print(input_columns)
print(len(input_columns))
# Out:
# ['members', 'genres_le', 'source_le', 'type_count', 'studios_count', 'producers_count', 'anime_id_count', 'TV', 'Special', 'Movie', 'Unknown_type', 'ONA', 'OVA', 'Music', 'PG-13 - Teens 13 or older', 'R+ - Mild Nudity', 'R - 17+ (violence & profanity)', 'G - All Ages', 'PG - Children', 'Rx - Hentai', 'Unknown_rate']
# 21

# %%
test_df = pd.concat([test_df, test_feat_df], axis=1)
test_df = test_df[input_columns]

# %%
# k 個のモデルの予測を作成. shape = (5, N_test,).
pred = np.array([model.predict(test_df.values) for model in models])


# k 個のモデルの予測値の平均 shape = (N_test,).
pred = np.mean(pred, axis=0) # axis=0 なので shape の `k` が潰れる

# %% [markdown]
# ## Inference predictions

# %%
fig, ax = plt.subplots(figsize=(8, 6))

vmax = .02
bins = np.linspace(0, 10, 100)
ax.hist(pred, bins=bins, density=True, alpha=.5, label="Test")
ax.hist(oof, bins=bins, density=True, alpha=.5, label="OutOfFold")
ax.grid()
ax.legend()
# ax.set_title("テストと学習時の予測傾向差分")

fig.tight_layout()

# %% [markdown]
# # save infer csv

# %%
pd.DataFrame({
    "score": pred
}).to_csv(os.path.join(configs.OUTPUT_DIR, "submission.csv"), index=False)

# %%
oof_score
# Out:
# 1.6864456778032515

# %%
if configs.wandb_available:
    wandb.log({"oof_score": oof_score})
    wandb.finish()
